# %%
import pandas as pd
from ydata_profiling import ProfileReport
import csv
import missingno as msno

# %% [markdown]
# # solution

# %%
a = pd.read_csv('data/darkness-dataset.csv',sep=';', header=None)
a
# Out:
#                                                     0  \
# 0   id,name,country_code,position,city,current_com...
# 1   random-id-2468,"Random Name","KW","","Kuwait",...
# 2   random-id-1357,"Random Name","IN","Random EduT...
# 3   random-id-8642,"Random Name","","","","{""comp...
# 4   random-id-9512,"Random Name","UK","Design Engi...
# 5   random-id-8642,"Random Name","KW","","Kuwait",...
# 6   random-id-7531,"Random Name","KW","","Kuwait",...
# 7   random-id-7890,"Random Name","DZ","Logging Ope...
# 8   random-id-4820,"Random Name","NG","Volkswagen ...
# 9   random-id-9025,"Random Name","UK","","","{""co...
# 10  random-id-5837,"Random Name","EG","Food Safety...
# 11  random-id-5847,"Random Name","GB","Community A...
# 12  random-id-12286a197,"Random Name","EG","Senior...
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# ...

# %%
def lec(row):
    lecteur_csv = csv.reader([row])
    result = []
    
    for i in lecteur_csv:
        result = i 
        
        return result  

    return result

# %%
def lecture_par_ligne(row):
    return next(csv.reader([row]))

# %%
# dataList = a[0].apply(lecture_par_ligne)

# %%
dataList = a[0].apply(lec)
data = pd.DataFrame(dataList.tolist())

# %%
data
# Out:
#                      0            1             2   \
# 0                    id         name  country_code
# 1        random-id-2468  Random Name            KW
# 2        random-id-1357  Random Name            IN
# 3        random-id-8642  Random Name
# 4        random-id-9512  Random Name            UK
# 5        random-id-8642  Random Name            KW
# 6        random-id-7531  Random Name            KW
# 7        random-id-7890  Random Name            DZ
# 8        random-id-4820  Random Name            NG
# 9        random-id-9025  Random Name            UK
# 10       random-id-5837  Random Name            EG
# 11       random-id-5847  Random Name            GB
# 12  random-id-12286a197  Random Name            EG
#
#                                                    3   \
# 0                                            position
# 1
# 2                                      Random EduTech
# 3
# 4   Design Engineer (System health) at Random Powe...
# 5
# 6
# ...

# %%
df_final = data.rename(columns=
{0:'id',
 1:'name',
 2:'country_code',
 3:'position',
 4:'city',
 5:'current_company',
 6:'about',
 7:'posts',
 8:'experience',
 9:'url',
 10:'people_also_viewed',
 11:'educations_details',
 12:'education',
 13:'recommendations_count',
 14:'avatar',
 15:'languages',
 16:'certifications',
 17:'recommendations',
 18:'volunteer_experience',
 19:'courses',
 20:'followers',
 21:'connections',
 22:'current_company_company_id',
 23:'current_company_name',
 24:'publications',
 25:'patents',
 26:'projects',
 27:'organizations',
 28:'input_url',
 29:'linkedin_id;;;;'})

# %%
df_final
# Out:
#                      id         name  country_code  \
# 0                    id         name  country_code
# 1        random-id-2468  Random Name            KW
# 2        random-id-1357  Random Name            IN
# 3        random-id-8642  Random Name
# 4        random-id-9512  Random Name            UK
# 5        random-id-8642  Random Name            KW
# 6        random-id-7531  Random Name            KW
# 7        random-id-7890  Random Name            DZ
# 8        random-id-4820  Random Name            NG
# 9        random-id-9025  Random Name            UK
# 10       random-id-5837  Random Name            EG
# 11       random-id-5847  Random Name            GB
# 12  random-id-12286a197  Random Name            EG
#
#                                              position  \
# 0                                            position
# 1
# 2                                      Random EduTech
# 3
# 4   Design Engineer (System health) at Random Powe...
# 5
# 6
# ...

# %%
df_final = df_final.drop(data.index[0])

# %%
df_final.columns
# Out:
# Index(['id', 'name', 'country_code', 'position', 'city', 'current_company',
#        'about', 'posts', 'experience', 'url', 'people_also_viewed',
#        'educations_details', 'education', 'recommendations_count', 'avatar',
#        'languages', 'certifications', 'recommendations',
#        'volunteer_experience', 'courses', 'followers', 'connections',
#        'current_company_company_id', 'current_company_name', 'publications',
#        'patents', 'projects', 'organizations', 'input_url', 'linkedin_id;;;;'],
#       dtype='object')

# %%
df_final.head(1)
# Out:
#                id         name country_code position    city  \
# 1  random-id-2468  Random Name           KW           Kuwait
#
#                                      current_company  \
# 1  {"company_id":"-seara","industry":"Seara Alime...
#
#                                                about  \
# 1  Experienced Unit Sales Manager with a demonstr...
#
#                                                posts experience  \
# 1  [{"attribution":"By Random Name","created_at":...
#
#                                           url  \
# 1  https://www.linkedin.com/in/random-id-2468
#
#                                   people_also_viewed     educations_details  \
# 1  [{"profile_link":"https://kw.linkedin.com/in/m...  Alexandria University
#
#   education recommendations_count  \
# 1
#
#                                               avatar  \
# 1  https://media.licdn.com/dms/image/D4D03AQEK_J4...
#
#                                            languages certifications  \
# ...
